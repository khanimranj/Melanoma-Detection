# %%
import matplotlib.pyplot as plt
import numpy as np
import PIL
import tensorflow as tf
import pathlib
from tensorflow import keras
from tensorflow.keras import layers
from tensorflow.keras.models import Sequential
import pandas as pd
import os
from glob import glob
from tensorflow.keras.preprocessing.image import load_img
tf.get_logger().setLevel('ERROR')

# %%
# Setting the path to both the train and test data
data_dir_train = pathlib.Path("CNN_assignment\Skin cancer ISIC The International Skin Imaging Collaboration\Train\\")
data_dir_test = pathlib.Path("CNN_assignment\Skin cancer ISIC The International Skin Imaging Collaboration\Test\\")

# %%
#Counting the number of images in train directory
image_count = len(list(data_dir_train.glob('*/*.jpg')))
print("Number of Images in Train is : ",image_count)
#Counting the number of images in test directory
image_count = len(list(data_dir_test.glob('*/*.jpg')))
print("Number of Images in Test is : ",image_count)
# Out:
# Number of Images in Train is :  2239
# Number of Images in Test is :  118

# %%
# Specifying Parameter to load images from directory using Keras
batch_size = 32
img_height = 180
img_width = 180

# %%
# Creating Training Dataset with 80% of the images
train_ds = tf.keras.utils.image_dataset_from_directory(
  data_dir_train,
  validation_split=0.2, # 80-20 Split with 80% for training and 20% for validation
  subset="training",
  seed=123,
  image_size=(img_height, img_width),
  batch_size=batch_size)
# Out:
# Found 2239 files belonging to 9 classes.
# Using 1792 files for training.

# %%
# Creating Validation Dataset with 20% of the images
val_ds = tf.keras.utils.image_dataset_from_directory(
  data_dir_train,
  validation_split=0.2, # 80-20 Split with 80% for training and 20% for validation
  subset="validation", 
  seed=123,
  image_size=(img_height, img_width),
  batch_size=batch_size)
# Out:
# Found 2239 files belonging to 9 classes.
# Using 447 files for validation.

# %%
# Getting Class names from the train.ds dataset and displaying the name and the number of classes
class_names = train_ds.class_names
print("The Number of Classes in the Training Dataset is :",len(class_names))
print("The label of the classes are as follow :")
for names in class_names:
    print(names)
# Out:
# The Number of Classes in the Training Dataset is : 9
# The label of the classes are as follow :
# actinic keratosis
# basal cell carcinoma
# dermatofibroma
# melanoma
# nevus
# pigmented benign keratosis
# seborrheic keratosis
# squamous cell carcinoma
# vascular lesion

# %%
# Unbatching train_ds to check for class distribtion and display 1 image from every class
dataset_unbatched = tuple(train_ds.unbatch())

# %%
# Display 1 image from every class
plt.figure(figsize=(10, 10))
found=0 # Counter to stop iteration after 1 instance of each class(Total of 9) has been found
for (image,label) in dataset_unbatched:
    if(found==9):
        break
    else:
        if(label.numpy()==found):
            ax = plt.subplot(3, 3,found+1)
            plt.imshow(image.numpy().astype("uint8"))
            plt.title(class_names[found])
            found +=1

# %%
#Checking class distribution in the train_ds dataset
labels = []
for (image,label) in dataset_unbatched:
    labels.append(label.numpy())
labels = pd.Series(labels)
count = labels.value_counts().sort_index()
count.index = train_ds.class_names
count = count.sort_values(ascending=False)
count
# Out:
# pigmented benign keratosis    370
# melanoma                      352
# basal cell carcinoma          309
# nevus                         277
# squamous cell carcinoma       142
# vascular lesion               115
# actinic keratosis              92
# dermatofibroma                 77
# seborrheic keratosis           58
# dtype: int64

# %%
count.plot.bar(count)
# Out:
# <AxesSubplot:>

# %%
## Class Imbalance seen##
#There is a huge class imbalance in the train.ds dataset. As can be seen from the graph and the list above.
#The range of number of images of from 370(in pigmented benign keratosis) to 58(in seborrheic keratosis)
#We will take care of this later during model building

# %%
# Checking Batch details
for image_batch, labels_batch in train_ds.take(1):
    print("The Details of each batch are as follow:")
    print("*"*20)
    print("The Number of images in each batch is :", image_batch.shape[0])
    print("The Height of images in the batch is :", image_batch.shape[1])
    print("The Width of images in the batch is :", image_batch.shape[2])
    print("The Number of Channels in each image is :", image_batch.shape[3])
    print("The Number of labels, which correspondent to the number of images - One Label per image in batch is : ",labels_batch.shape[0])
    print()
    break
# Out:
# The Details of each batch are as follow:
# ********************
# The Number of images in each batch is : 32
# The Height of images in the batch is : 180
# The Width of images in the batch is : 180
# The Number of Channels in each image is : 3
# The Number of labels, which correspondent to the number of images - One Label per image in batch is :  32

# %%
# Reusable code to plot model accuracy anmd loss
#Repurposed from starter sheet
def plotmodel(modelhistory):
    acc = modelhistory.history['accuracy']
    val_acc = modelhistory.history['val_accuracy']

    loss = modelhistory.history['loss']
    val_loss = modelhistory.history['val_loss']

    epochs_range = range(epochs)

    plt.figure(figsize=(10, 5))
    plt.subplot(1, 2, 1)
    plt.plot(epochs_range, acc, label='Training Accuracy')
    plt.plot(epochs_range, val_acc, label='Validation Accuracy')
    plt.legend(loc='lower right')
    plt.title('Training and Validation Accuracy')

    plt.subplot(1, 2, 2)
    plt.plot(epochs_range, loss, label='Training Loss')
    plt.plot(epochs_range, val_loss, label='Validation Loss')


    plt.legend(loc='upper right')
    plt.title('Training and Validation Loss')
    plt.show()

# %%
# Setting Cache and Prefetch using Keras AUTOTUNE
#Please note: This will be called before every model so that the cache is shuffled
AUTOTUNE = tf.data.AUTOTUNE
train_ds = train_ds.cache().shuffle(1000).prefetch(buffer_size=AUTOTUNE)
val_ds = val_ds.cache().prefetch(buffer_size=AUTOTUNE)

# %%
#Model 1 
# No Batch Normalization
# No Dropout
model_1 = Sequential([
    #Rescaling Layer
    layers.Rescaling(1./255, input_shape=(img_height, img_width, 3)),
    #Layer 1
    layers.Conv2D(16,3,padding="same", activation='relu'),
    layers.MaxPooling2D(),
    #Layer 2
    layers.Conv2D(32,3,padding="same", activation='relu'),
    layers.MaxPooling2D(),
    #Layer 3
    layers.Conv2D(64,3,padding="same", activation='relu'),
    layers.MaxPooling2D(),
    #Flatten Layer
    layers.Flatten(),
    #Dense Layer
    layers.Dense(128,activation='relu'),
    #Softmax Layer
    layers.Dense(len(class_names),activation='softmax'),
])

# %%
# Compiling the model and specifying Optimizer,loss function and metric to be used
# Using sparse_categorical_crossentropy as loss as it is a multiclass classification model
model_1.compile(optimizer="Adam",loss="sparse_categorical_crossentropy",metrics=["accuracy"])

# %%
#Checking Model Summary
model_1.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  rescaling (Rescaling)       (None, 180, 180, 3)       0
#
#  conv2d (Conv2D)             (None, 180, 180, 16)      448
#
#  max_pooling2d (MaxPooling2D  (None, 90, 90, 16)       0
#  )
#
#  conv2d_1 (Conv2D)           (None, 90, 90, 32)        4640
#
#  max_pooling2d_1 (MaxPooling  (None, 45, 45, 32)       0
#  2D)
#
#  conv2d_2 (Conv2D)           (None, 45, 45, 64)        18496
#
#  max_pooling2d_2 (MaxPooling  (None, 22, 22, 64)       0
#  2D)
#
#  flatten (Flatten)           (None, 30976)             0
#
#  dense (Dense)               (None, 128)               3965056
#
#  dense_1 (Dense)             (None, 9)                 1161
#
# =================================================================
# Total params: 3,989,801
# Trainable params: 3,989,801
# Non-trainable params: 0
# _________________________________________________________________

# %%
#Running the model for 20 epochs
epochs = 20
history_1 = model_1.fit(train_ds,validation_data=val_ds,epochs=epochs)
# Out:
# Epoch 1/20
# 56/56 [==============================] - 8s 48ms/step - loss: 1.9438 - accuracy: 0.2623 - val_loss: 1.7035 - val_accuracy: 0.3826
# Epoch 2/20
# 56/56 [==============================] - 2s 28ms/step - loss: 1.5792 - accuracy: 0.4353 - val_loss: 1.4733 - val_accuracy: 0.5302
# Epoch 3/20
# 56/56 [==============================] - 2s 28ms/step - loss: 1.4917 - accuracy: 0.4983 - val_loss: 1.4410 - val_accuracy: 0.5213
# Epoch 4/20
# 56/56 [==============================] - 2s 28ms/step - loss: 1.3633 - accuracy: 0.5218 - val_loss: 1.4170 - val_accuracy: 0.4966
# Epoch 5/20
# 56/56 [==============================] - 2s 28ms/step - loss: 1.2318 - accuracy: 0.5513 - val_loss: 1.4794 - val_accuracy: 0.5145
# Epoch 6/20
# 56/56 [==============================] - 2s 28ms/step - loss: 1.1478 - accuracy: 0.5921 - val_loss: 1.4217 - val_accuracy: 0.5570
# Epoch 7/20
# 56/56 [==============================] - 2s 28ms/step - loss: 1.1104 - accuracy: 0.6211 - val_loss: 1.3657 - val_accuracy: 0.5347
# Epoch 8/20
# 56/56 [==============================] - 2s 28ms/step - loss: 0.9748 - accuracy: 0.6507 - val_loss: 1.3788 - val_accuracy: 0.5570
# Epoch 9/20
# 56/56 [==============================] - 2s 28ms/step - loss: 0.9080 - accuracy: 0.6652 - val_loss: 1.4143 - val_accuracy: 0.5324
# Epoch 10/20
# 56/56 [==============================] - 2s 28ms/step - loss: 0.8757 - accuracy: 0.6786 - val_loss: 1.3952 - val_accuracy: 0.5436
# Epoch 11/20
# 56/56 [==============================] - 2s 28ms/step - loss: 0.8040 - accuracy: 0.7098 - val_loss: 1.4531 - val_accuracy: 0.5615
# Epoch 12/20
# 56/56 [==============================] - 2s 28ms/step - loss: 0.7038 - accuracy: 0.7455 - val_loss: 1.4282 - val_accuracy: 0.5436
# Epoch 13/20
# 56/56 [==============================] - 2s 28ms/step - loss: 0.6555 - accuracy: 0.7595 - val_loss: 1.7716 - val_accuracy: 0.5459
# Epoch 14/20
# 56/56 [==============================] - 2s 28ms/step - loss: 0.5976 - accuracy: 0.7902 - val_loss: 1.6796 - val_accuracy: 0.5324
# Epoch 15/20
# 56/56 [==============================] - 2s 28ms/step - loss: 0.5058 - accuracy: 0.8153 - val_loss: 1.7409 - val_accuracy: 0.4922
# Epoch 16/20
# 56/56 [==============================] - 2s 28ms/step - loss: 0.4336 - accuracy: 0.8387 - val_loss: 1.9011 - val_accuracy: 0.5324
# Epoch 17/20
# 56/56 [==============================] - 2s 28ms/step - loss: 0.4247 - accuracy: 0.8404 - val_loss: 2.0383 - val_accuracy: 0.5324
# Epoch 18/20
# 56/56 [==============================] - 2s 28ms/step - loss: 0.3782 - accuracy: 0.8555 - val_loss: 1.9368 - val_accuracy: 0.5459
# Epoch 19/20
# 56/56 [==============================] - 2s 28ms/step - loss: 0.3170 - accuracy: 0.8761 - val_loss: 2.3555 - val_accuracy: 0.4966
# Epoch 20/20
# 56/56 [==============================] - 2s 28ms/step - loss: 0.2851 - accuracy: 0.8817 - val_loss: 2.2780 - val_accuracy: 0.5168

# %%
plotmodel(history_1)

# %% [markdown]
# Observation for model_1
#
# From the graphs we can see that the model has very low accuracy on validation data but very high accuracy on training data., Also as the epochs increase the training loss is also decreasing very fast, this is a clear example of overfitting

# %% [markdown]
# Solving Overfit - Data Augmentation
#
# One of the way we can try and solve overfitting is by data augmentation.
#
# Here we will use keras to help us generate augmented data

# %%
# Setting the parameters for the augmentation
#Here Augmentation refers to the process of changing the original image by flipping, rotating, zoom (and/or)
data_augmentation = tf.keras.Sequential([
  layers.RandomFlip("horizontal_and_vertical"),
  layers.RandomRotation(0.5),
    layers.RandomZoom(0.2)
])

# %%
# Lets look at 4 random images after they have been augmented instead of just one
plt.figure(figsize=(10, 6))
position=1
for image, label in train_ds.take(1):
    for i in range(4):
        ax = plt.subplot(2, 4, position)
        plt.title("Original")
        plt.imshow(image[i].numpy().astype("uint8"))
        augmented_image = data_augmentation(image[i])
        position +=1
        ax = plt.subplot(2, 4, position)
        plt.title("Augmented")
        plt.imshow(augmented_image.numpy().astype("uint8"))
        position +=1

# %%
#Let us apply the augmentation to the train_ds
# Also please note , augmentation will only be applied to training dataset and not validation or test


train_ds = train_ds.map(lambda x, y: (data_augmentation(x, training=True), y), num_parallel_calls=AUTOTUNE)

# %%
# Setting Cache and Prefetch using Keras AUTOTUNE
#Please note: This will be called before every model so that the cache is shuffled
AUTOTUNE = tf.data.AUTOTUNE
train_ds = train_ds.cache().shuffle(1000).prefetch(buffer_size=AUTOTUNE)
val_ds = val_ds.cache().prefetch(buffer_size=AUTOTUNE)

# %%
# Model_2
# No Batch normalization
# No Dropouts
#Please note data augmentation has been mapped above and will not be called during model building here

model_2 = Sequential([
    layers.Rescaling(1./255, input_shape=(img_height, img_width, 3)),
    #Layer 1
    layers.Conv2D(16,3,padding="same", activation='relu'),
    layers.MaxPooling2D(),
    #Layer 2
    layers.Conv2D(32,3,padding="same", activation='relu'),
    layers.MaxPooling2D(),
    #Layer 3
    layers.Conv2D(64,3,padding="same", activation='relu'),
    layers.MaxPooling2D(),
    #Flatten Layer
    layers.Flatten(),
    #Dense Layer
    layers.Dense(128,activation='relu'),
    #Softmax Layer
    layers.Dense(len(class_names),activation='softmax'),
])

# %%
# Compiling the model and specifying Optimizer,loss function and metric to be used
# Using sparse_categorical_crossentropy as loss as it is a multiclass classification model
model_2.compile(optimizer="Adam",loss="sparse_categorical_crossentropy",metrics=["accuracy"])

# %%
#Checking Model Summary
model_2.summary()
# Out:
# Model: "sequential_2"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  rescaling_1 (Rescaling)     (None, 180, 180, 3)       0
#
#  conv2d_3 (Conv2D)           (None, 180, 180, 16)      448
#
#  max_pooling2d_3 (MaxPooling  (None, 90, 90, 16)       0
#  2D)
#
#  conv2d_4 (Conv2D)           (None, 90, 90, 32)        4640
#
#  max_pooling2d_4 (MaxPooling  (None, 45, 45, 32)       0
#  2D)
#
#  conv2d_5 (Conv2D)           (None, 45, 45, 64)        18496
#
#  max_pooling2d_5 (MaxPooling  (None, 22, 22, 64)       0
#  2D)
#
#  flatten_1 (Flatten)         (None, 30976)             0
#
#  dense_2 (Dense)             (None, 128)               3965056
#
#  dense_3 (Dense)             (None, 9)                 1161
#
# =================================================================
# Total params: 3,989,801
# Trainable params: 3,989,801
# Non-trainable params: 0
# _________________________________________________________________

# %%
#Running the model for 20 epochs
epochs = 20
history_2 = model_2.fit(train_ds,validation_data=val_ds,epochs=epochs)
# Out:
# Epoch 1/20
# 56/56 [==============================] - 5s 31ms/step - loss: 1.9336 - accuracy: 0.3142 - val_loss: 1.6391 - val_accuracy: 0.4273
# Epoch 2/20
# 56/56 [==============================] - 2s 28ms/step - loss: 1.6145 - accuracy: 0.4319 - val_loss: 1.4838 - val_accuracy: 0.5034
# Epoch 3/20
# 56/56 [==============================] - 2s 28ms/step - loss: 1.4983 - accuracy: 0.4777 - val_loss: 1.5412 - val_accuracy: 0.4743
# Epoch 4/20
# 56/56 [==============================] - 2s 29ms/step - loss: 1.3877 - accuracy: 0.5061 - val_loss: 1.4456 - val_accuracy: 0.5190
# Epoch 5/20
# 56/56 [==============================] - 2s 28ms/step - loss: 1.3247 - accuracy: 0.5234 - val_loss: 1.5404 - val_accuracy: 0.5078
# Epoch 6/20
# 56/56 [==============================] - 2s 28ms/step - loss: 1.2587 - accuracy: 0.5536 - val_loss: 1.4248 - val_accuracy: 0.5168
# Epoch 7/20
# 56/56 [==============================] - 2s 28ms/step - loss: 1.1695 - accuracy: 0.5781 - val_loss: 1.6334 - val_accuracy: 0.5101
# Epoch 8/20
# 56/56 [==============================] - 2s 28ms/step - loss: 1.0942 - accuracy: 0.6021 - val_loss: 1.6128 - val_accuracy: 0.5011
# Epoch 9/20
# 56/56 [==============================] - 2s 28ms/step - loss: 1.0331 - accuracy: 0.6233 - val_loss: 1.6847 - val_accuracy: 0.4899
# Epoch 10/20
# 56/56 [==============================] - 2s 28ms/step - loss: 0.9886 - accuracy: 0.6334 - val_loss: 1.7797 - val_accuracy: 0.5145
# Epoch 11/20
# 56/56 [==============================] - 2s 28ms/step - loss: 0.9330 - accuracy: 0.6585 - val_loss: 2.0267 - val_accuracy: 0.4407
# Epoch 12/20
# 56/56 [==============================] - 2s 28ms/step - loss: 0.8482 - accuracy: 0.6869 - val_loss: 1.9193 - val_accuracy: 0.4877
# Epoch 13/20
# 56/56 [==============================] - 2s 28ms/step - loss: 0.7172 - accuracy: 0.7444 - val_loss: 2.2081 - val_accuracy: 0.4720
# Epoch 14/20
# 56/56 [==============================] - 2s 28ms/step - loss: 0.6740 - accuracy: 0.7662 - val_loss: 2.6266 - val_accuracy: 0.4944
# Epoch 15/20
# 56/56 [==============================] - 2s 28ms/step - loss: 0.6331 - accuracy: 0.7695 - val_loss: 2.7823 - val_accuracy: 0.4631
# Epoch 16/20
# 56/56 [==============================] - 2s 28ms/step - loss: 0.4574 - accuracy: 0.8421 - val_loss: 2.5236 - val_accuracy: 0.4564
# Epoch 17/20
# 56/56 [==============================] - 2s 28ms/step - loss: 0.4159 - accuracy: 0.8594 - val_loss: 3.3406 - val_accuracy: 0.4541
# Epoch 18/20
# 56/56 [==============================] - 2s 28ms/step - loss: 0.3257 - accuracy: 0.8956 - val_loss: 3.4909 - val_accuracy: 0.4832
# Epoch 19/20
# 56/56 [==============================] - 2s 28ms/step - loss: 0.2849 - accuracy: 0.9057 - val_loss: 3.4510 - val_accuracy: 0.4340
# Epoch 20/20
# 56/56 [==============================] - 2s 28ms/step - loss: 0.2690 - accuracy: 0.9018 - val_loss: 3.9631 - val_accuracy: 0.4318

# %%
plotmodel(history_2)

# %% [markdown]
#  Observation for Model_2
#
# The model is performing well on training dataset but is not performning well on validation. Our strategy to do in-place augmentation to prevent overfitting hasn't worked
#
# Also as we noted before the building the 1st model there is a huge class imbalance in the training dataset and we will have to find a way to rectify this

# %%
#The number of images per class is as follows:
count
# Out:
# pigmented benign keratosis    370
# melanoma                      352
# basal cell carcinoma          309
# nevus                         277
# squamous cell carcinoma       142
# vascular lesion               115
# actinic keratosis              92
# dermatofibroma                 77
# seborrheic keratosis           58
# dtype: int64

# %% [markdown]
# Solving class imbalance
#
# Here we will use the Augmentor library to generate augmented images from the original images that can be added to the dataset to ease the difference in number of data points per class

# %%
#install Augmentor
# !pip install Augmentor
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: Augmentor in c:\users\perrymason\appdata\roaming\python\python39\site-packages (0.2.10)
# Requirement already satisfied: numpy>=1.11.0 in c:\programdata\anaconda3\lib\site-packages (from Augmentor) (1.21.5)
# Requirement already satisfied: Pillow>=5.2.0 in c:\programdata\anaconda3\lib\site-packages (from Augmentor) (9.2.0)
# Requirement already satisfied: tqdm>=4.9.0 in c:\programdata\anaconda3\lib\site-packages (from Augmentor) (4.64.1)
# Requirement already satisfied: future>=0.16.0 in c:\programdata\anaconda3\lib\site-packages (from Augmentor) (0.18.2)
# Requirement already satisfied: colorama in c:\programdata\anaconda3\lib\site-packages (from tqdm>=4.9.0->Augmentor) (0.4.5)

# %%
# Start the augmentor to add images to the train data directory
# Parameters used : Rotate -45 to +45 degree with a probability of 0.7 and zoom between 
# 1.1 to 1.25 with the probability of 0.3

path_to_training_dataset="CNN_assignment\Skin cancer ISIC The International Skin Imaging Collaboration\Train\\"
import Augmentor
for i in class_names:
    p = Augmentor.Pipeline(path_to_training_dataset + i)
    p.rotate(probability=0.7, max_left_rotation=25, max_right_rotation=25)
    p.zoom(probability=0.3, min_factor=1.1, max_factor=1.25)
    p.sample(500)  #Adding 500 samples per class to make sure that none of the classes are sparse
# Out:
# Initialised with 114 image(s) found.
# Output directory set to CNN_assignment\Skin cancer ISIC The International Skin Imaging Collaboration\Train\actinic keratosis\output.
# Processing <PIL.Image.Image image mode=RGB size=600x450 at 0x19DD60A6250>: 100%|█| 5
# Initialised with 376 image(s) found.
# Output directory set to CNN_assignment\Skin cancer ISIC The International Skin Imaging Collaboration\Train\basal cell carcinoma\output.
# Processing <PIL.Image.Image image mode=RGB size=600x450 at 0x19C7FA73160>: 100%|█| 5
# Initialised with 95 image(s) found.
# Output directory set to CNN_assignment\Skin cancer ISIC The International Skin Imaging Collaboration\Train\dermatofibroma\output.
# Processing <PIL.Image.Image image mode=RGB size=600x450 at 0x19D9581CA60>: 100%|█| 5
# Initialised with 438 image(s) found.
# Output directory set to CNN_assignment\Skin cancer ISIC The International Skin Imaging Collaboration\Train\melanoma\output.
# Processing <PIL.Image.Image image mode=RGB size=1024x768 at 0x19DC370AB50>: 100%|█|
# Initialised with 357 image(s) found.
# Output directory set to CNN_assignment\Skin cancer ISIC The International Skin Imaging Collaboration\Train\nevus\output.
# Processing <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=2048x1536 at 0x19D
# Initialised with 462 image(s) found.
# Output directory set to CNN_assignment\Skin cancer ISIC The International Skin Imaging Collaboration\Train\pigmented benign keratosis\output.
# Processing <PIL.Image.Image image mode=RGB size=600x450 at 0x19C7F9A3CA0>: 100%|█| 5
# Initialised with 77 image(s) found.
# Output directory set to CNN_assignment\Skin cancer ISIC The International Skin Imaging Collaboration\Train\seborrheic keratosis\output.
# Processing <PIL.Image.Image image mode=RGB size=1024x768 at 0x19C7FA01D60>: 100%|█|
# Initialised with 181 image(s) found.
# Output directory set to CNN_assignment\Skin cancer ISIC The International Skin Imaging Collaboration\Train\squamous cell carcinoma\output.
# Processing <PIL.Image.Image image mode=RGB size=600x450 at 0x19C7FAB55B0>: 100%|█| 5
# Initialised with 139 image(s) found.
# Output directory set to CNN_assignment\Skin cancer ISIC The International Skin Imaging Collaboration\Train\vascular lesion\output.
# Processing <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=600x450 at 0x19DD5

# %%
#Checking to see how many new images were added 
image_count_train = len(list(data_dir_train.glob('*/output/*.jpg')))
print(image_count_train)
# Out:
# 4500

# %%
# Creating new training and validation dataset
# Checking new class distribution
#The train_ds and val_ds has to be rebuild as the data in the directory has increased

# %%
# Creating Training Dataset with 80% of the images
train_ds = tf.keras.utils.image_dataset_from_directory(
  data_dir_train,
  validation_split=0.2, # 80-20 Split with 80% for training and 20% for validation
  subset="training",
  seed=123,
  image_size=(img_height, img_width),
  batch_size=batch_size)
# Out:
# Found 6739 files belonging to 9 classes.
# Using 5392 files for training.

# %%
# Creating Validation Dataset with 20% of the images
val_ds = tf.keras.utils.image_dataset_from_directory(
  data_dir_train,
  validation_split=0.2, # 80-20 Split with 80% for training and 20% for validation
  subset="validation", 
  seed=123,
  image_size=(img_height, img_width),
  batch_size=batch_size)
# Out:
# Found 6739 files belonging to 9 classes.
# Using 1347 files for validation.

# %%
#Checking class distribution in the new train_ds dataset
dataset_unbatched = tuple(train_ds.unbatch())
labels = []
for (image,label) in dataset_unbatched:
    labels.append(label.numpy())
labels = pd.Series(labels)
count = labels.value_counts().sort_index()
count.index = train_ds.class_names
count = count.sort_values(ascending=False)
count
# Out:
# pigmented benign keratosis    773
# melanoma                      755
# basal cell carcinoma          721
# nevus                         677
# squamous cell carcinoma       569
# actinic keratosis             493
# vascular lesion               493
# seborrheic keratosis          456
# dermatofibroma                455
# dtype: int64

# %%
count.plot.bar(count)
# Out:
# <AxesSubplot:>

# %%
# The class imbalance hasn't been totally solved but the imbalance has been reduced

# %%
# Setting Cache and Prefetch using Keras AUTOTUNE
#Please note: This will be called before every model so that the cache is shuffled
AUTOTUNE = tf.data.AUTOTUNE
train_ds = train_ds.cache().shuffle(1000).prefetch(buffer_size=AUTOTUNE)
val_ds = val_ds.cache().prefetch(buffer_size=AUTOTUNE)

# %%
# Model_3
# Added batch normalization layer
# No Dropout
model_3 = Sequential([
    layers.Rescaling(1./255, input_shape=(img_height, img_width, 3)),
    #Layer 1
    layers.Conv2D(16,3,padding="same", activation='relu'),
    layers.BatchNormalization(),
    layers.MaxPooling2D(),
    #Layer 2
    layers.Conv2D(32,3,padding="same", activation='relu'),
    layers.BatchNormalization(),
    layers.MaxPooling2D(),
    #Layer 3
    layers.Conv2D(64,3,padding="same", activation='relu'),
    layers.BatchNormalization(),
    layers.MaxPooling2D(),
    #Flatten Layer
    layers.Flatten(),
    #Dense Layer
    layers.Dense(128,activation='relu'),
    #Softmax Layer
    layers.Dense(len(class_names),activation='softmax'),
])

# %%
# Compiling the model and specifying Optimizer,loss function and metric to be used
# Using sparse_categorical_crossentropy as loss as it is a multiclass classification model
model_3.compile(optimizer="Adam",loss="sparse_categorical_crossentropy",metrics=["accuracy"])

# %%
#Checking model Summary
model_3.summary()
# Out:
# Model: "sequential_3"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  rescaling_2 (Rescaling)     (None, 180, 180, 3)       0
#
#  conv2d_6 (Conv2D)           (None, 180, 180, 16)      448
#
#  batch_normalization (BatchN  (None, 180, 180, 16)     64
#  ormalization)
#
#  max_pooling2d_6 (MaxPooling  (None, 90, 90, 16)       0
#  2D)
#
#  conv2d_7 (Conv2D)           (None, 90, 90, 32)        4640
#
#  batch_normalization_1 (Batc  (None, 90, 90, 32)       128
#  hNormalization)
#
#  max_pooling2d_7 (MaxPooling  (None, 45, 45, 32)       0
#  2D)
#
#  conv2d_8 (Conv2D)           (None, 45, 45, 64)        18496
#
#  batch_normalization_2 (Batc  (None, 45, 45, 64)       256
#  hNormalization)
#
#  max_pooling2d_8 (MaxPooling  (None, 22, 22, 64)       0
#  2D)
#
#  flatten_2 (Flatten)         (None, 30976)             0
#
#  dense_4 (Dense)             (None, 128)               3965056
#
#  dense_5 (Dense)             (None, 9)                 1161
#
# =================================================================
# Total params: 3,990,249
# Trainable params: 3,990,025
# Non-trainable params: 224
# _________________________________________________________________

# %%
#Running the model for 30 epochs
epochs = 50
history_3 = model_3.fit(train_ds,validation_data=val_ds,epochs=epochs)
# Out:
# Epoch 1/50
# 169/169 [==============================] - 16s 47ms/step - loss: 2.3837 - accuracy: 0.3490 - val_loss: 42.5284 - val_accuracy: 0.1039
# Epoch 2/50
# 169/169 [==============================] - 6s 35ms/step - loss: 1.3779 - accuracy: 0.4968 - val_loss: 13.2507 - val_accuracy: 0.1203
# Epoch 3/50
# 169/169 [==============================] - 6s 35ms/step - loss: 1.1428 - accuracy: 0.5742 - val_loss: 2.9058 - val_accuracy: 0.3556
# Epoch 4/50
# 169/169 [==============================] - 6s 35ms/step - loss: 0
50
# 169/169 [==============================] - 6s 35ms/step - loss: 0.0577 - accuracy: 0.9759 - val_loss: 1.8956 - val_accuracy: 0.6726
# Epoch 32/50
# 169/169 [==============================] - 6s 36ms/step - loss: 0.0544 - accuracy: 0.9772 - val_loss: 1.9003 - val_accuracy: 0.6778
# Epoch 33/50
# 169/169 [==============================] - 6s 36ms/step - loss: 0.0519 - accuracy: 0.9790 - val_loss: 3.7146 - val_accuracy: 0.5323
# Epoch 34/50
# 169/169 [==============================] - 6s 36ms/step - loss: 0.0533 - accuracy: 0.9779 - val_loss: 3.5650 - val_accuracy: 0.5457
# Epoch 35/50
# 169/169 [==============================] - 6s 36ms/step - loss: 0.0525 - accuracy: 0.9803 - val_loss: 2.2471 - val_accuracy: 0.6600
# Epoch 36/50
# 169/169 [==============================] - 6s 35ms/step - loss: 0.0431 - accuracy: 0.9839 - val_loss: 1.9183 - val_accuracy: 0.6882
# Epoch 37/50
# 169/169 [==============================] - 6s 36ms/step - loss: 0.0418 - accuracy: 0.9846 - val_loss: 2.0394 - val_accuracy: 0.6808
# Epoch 38/50
# 169/169 [==============================] - 6s 35ms/step - loss: 0.0637 - accuracy: 0.9785 - val_loss: 3.2597 - val_accuracy: 0.5650
# Epoch 39/50
# 169/169 [==============================] - 6s 35ms/step - loss: 0.2670 - accuracy: 0.9243 - val_loss: 3.2332 - val_accuracy: 0.5405
# Epoch 40/50
# 169/169 [==============================] - 6s 35ms/step - loss: 0.1660 - accuracy: 0.9481 - val_loss: 4.6629 - val_accuracy: 0.4491
# Epoch 41/50
# 169/169 [==============================] - 6s 35ms/step - loss: 0.0980 - accuracy: 0.9696 - val_loss: 2.5789 - val_accuracy: 0.6147
# Epoch 42/50
# 169/169 [==============================] - 6s 35ms/step - loss: 0.1199 - accuracy: 0.9655 - val_loss: 2.2013 - val_accuracy: 0.6333
# Epoch 43/50
# 169/169 [==============================] - 6s 35ms/step - loss: 0.0656 - accuracy: 0.9753 - val_loss: 2.7568 - val_accuracy: 0.5895
# Epoch 44/50
# 169/169 [==============================] - 6s 35ms/step - loss: 0.0556 - accuracy: 0.9828 - val_loss: 2.1949 - val_accuracy: 0.6622
# Epoch 45/50
# 169/169 [==============================] - 6s 35ms/step - loss: 0.0396 - accuracy: 0.9857 - val_loss: 2.4905 - val_accuracy: 0.6295
# Epoch 46/50
# 169/169 [==============================] - 6s 35ms/step - loss: 0.0447 - accuracy: 0.9831 - val_loss: 2.8158 - val_accuracy: 0.5984
# Epoch 47/50
# 169/169 [==============================] - 6s 35ms/step - loss: 0.0361 - accuracy: 0.9835 - val_loss: 2.5487 - val_accuracy: 0.6362
# Epoch 48/50
# 169/169 [==============================] - 6s 35ms/step - loss: 0.0410 - accuracy: 0.9850 - val_loss: 2.5263 - val_accuracy: 0.6281
# Epoch 49/50
# 169/169 [==============================] - 6s 36ms/step - loss: 0.0372 - accuracy: 0.9837 - val_loss: 2.6624 - val_accuracy: 0.6518
# Epoch 50/50
# 169/169 [==============================] - 6s 36ms/step - loss: 0.0380 - accuracy: 0.9835 - val_loss: 2.1498 - val_accuracy: 0.6771

# %%
plotmodel(history_3)

# %% [markdown]
#  Observation for Model_3
#
# The model is performing well on training dataset but is not performning well on validation.  But the handling the class balance has increased the validation accuracy considerably(43% to 67%). But there is still an issue of overfit

# %%
# Testing another model with different layers and configuration including dropouts

# %%
# Setting Cache and Prefetch using Keras AUTOTUNE
#Please note: This will be called before every model so that the cache is shuffled
AUTOTUNE = tf.data.AUTOTUNE
train_ds = train_ds.cache().shuffle(1000).prefetch(buffer_size=AUTOTUNE)
val_ds = val_ds.cache().prefetch(buffer_size=AUTOTUNE)

# %%
# Model 4 
# Increasing layers compared to previous model
# Batch Normalization layer present
# Dropout layer added
model_4 = Sequential([
    layers.Rescaling(1./255, input_shape=(img_height, img_width, 3)),
    #
    layers.Conv2D(16,3,padding="same", activation='relu'),
    layers.BatchNormalization(),
    layers.Conv2D(16,3, activation='relu'),
    layers.BatchNormalization(),
    layers.MaxPooling2D(pool_size=(2, 2)),
    layers.Dropout(0.25),
    #
    layers.Conv2D(32,3,padding="same", activation='relu'),
    layers.BatchNormalization(),
    layers.Conv2D(32,3, activation='relu'),
    layers.BatchNormalization(),
    layers.MaxPooling2D(pool_size=(2, 2)),
    layers.Dropout(0.25),
    #
    layers.Conv2D(64,3,padding="same", activation='relu'),
    layers.BatchNormalization(),
    layers.Conv2D(64,3, activation='relu'),
    layers.BatchNormalization(),
    layers.MaxPooling2D(pool_size=(2, 2)),
    layers.Dropout(0.25),
    #Flatten Layer
    layers.Flatten(),
    #Dense Layer
    layers.Dense(128,activation='relu'),
    layers.Dropout(0.25),
    #Softmax Layer
    layers.Dense(len(class_names),activation='softmax')
])

# %%
# Compiling the model and specifying Optimizer,loss function and metric to be used
# Using sparse_categorical_crossentropy as loss as it is a multiclass classification model
model_4.compile(optimizer="Adam",loss="sparse_categorical_crossentropy",metrics=["accuracy"])

# %%
#Checking Model Summary
model_4.summary()
# Out:
# Model: "sequential_4"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  rescaling_3 (Rescaling)     (None, 180, 180, 3)       0
#
#  conv2d_9 (Conv2D)           (None, 180, 180, 16)      448
#
#  batch_normalization_3 (Batc  (None, 180, 180, 16)     64
#  hNormalization)
#
#  conv2d_10 (Conv2D)          (None, 178, 178, 16)      2320
#
#  batch_normalization_4 (Batc  (None, 178, 178, 16)     64
#  hNormalization)
#
#  max_pooling2d_9 (MaxPooling  (None, 89, 89, 16)       0
#  2D)
#
#  dropout (Dropout)           (None, 89, 89, 16)        0
#
#  conv2d_11 (Conv2D)          (None, 89, 89, 32)        4640
#
#  batch_normalization_5 (Batc  (None, 89, 89, 32)       128
#  hNormalization)
#
#  conv2d_12 (Conv2D)          (None, 87, 87, 32)        9248
#
#  batch_normalization_6 (Batc  (None, 87, 87, 32)       128
#  hNormalization)
#
#  max_pooling2d_10 (MaxPoolin  (None, 43, 43, 32)       0
#  g2D)
#
#  dropout_1 (Dropout)         (None, 43, 43, 32)        0
#
#  conv2d_13 (Conv2D)          (None, 43, 43, 64)        18496
#
#  batch_normalization_7 (Batc  (None, 43, 43, 64)       256
#  hNormalization)
#
#  conv2d_14 (Conv2D)          (None, 41, 41, 64)        36928
#
#  batch_normalization_8 (Batc  (None, 41, 41, 64)       256
#  hNormalization)
#
#  max_pooling2d_11 (MaxPoolin  (None, 20, 20, 64)       0
#  g2D)
#
#  dropout_2 (Dropout)         (None, 20, 20, 64)        0
#
#  flatten_3 (Flatten)         (None, 25600)             0
#
#  dense_6 (Dense)             (None, 128)               3276928
#
#  dropout_3 (Dropout)         (None, 128)               0
#
#  dense_7 (Dense)             (None, 9)                 1161
#
# =================================================================
# Total params: 3,351,065
# Trainable params: 3,350,617
# Non-trainable params: 448
# _________________________________________________________________

# %%
epochs = 50
history_4 = model_4.fit(train_ds,validation_data=val_ds,epochs=epochs)
# Out:
# Epoch 1/50
# 169/169 [==============================] - 15s 77ms/step - loss: 2.5677 - accuracy: 0.2478 - val_loss: 15.7550 - val_accuracy: 0.1351
# Epoch 2/50
# 169/169 [==============================] - 12s 72ms/step - loss: 1.8440 - accuracy: 0.2954 - val_loss: 11.1683 - val_accuracy: 0.1299
# Epoch 3/50
# 169/169 [==============================] - 12s 73ms/step - loss: 1.8138 - accuracy: 0.2980 - val_loss: 2.8998 - val_accuracy: 0.3066
50
# 169/169 [==============================] - 12s 73ms/step - loss: 0.8877 - accuracy: 0.6350 - val_loss: 3.0808 - val_accuracy: 0.4150
# Epoch 24/50
# 169/169 [==============================] - 12s 73ms/step - loss: 0.9075 - accuracy: 0.6384 - val_loss: 1.2135 - val_accuracy: 0.5754
# Epoch 25/50
# 169/169 [==============================] - 12s 73ms/step - loss: 0.8543 - accuracy: 0.6515 - val_loss: 1.4130 - val_accuracy: 0.5709
# Epoch 26/50
# 169/169 [==============================] - 12s 73ms/step - loss: 0.8174 - accuracy: 0.6723 - val_loss: 1.2000 - val_accuracy: 0.5895
# Epoch 27/50
# 169/169 [==============================] - 12s 73ms/step - loss: 0.8035 - accuracy: 0.6734 - val_loss: 1.3207 - val_accuracy: 0.5791
# Epoch 28/50
# 169/169 [==============================] - 12s 73ms/step - loss: 0.8002 - accuracy: 0.6719 - val_loss: 3.4756 - val_accuracy: 0.4046
# Epoch 29/50
# 169/169 [==============================] - 12s 73ms/step - loss: 0.7674 - accuracy: 0.6949 - val_loss: 1.2807 - val_accuracy: 0.6102
# Epoch 30/50
# 169/169 [==============================] - 12s 73ms/step - loss: 0.7776 - accuracy: 0.6953 - val_loss: 1.1889 - val_accuracy: 0.6117
# Epoch 31/50
# 169/169 [==============================] - 12s 73ms/step - loss: 0.7125 - accuracy: 0.7055 - val_loss: 1.4573 - val_accuracy: 0.5783
# Epoch 32/50
# 169/169 [==============================] - 12s 73ms/step - loss: 0.6840 - accuracy: 0.7231 - val_loss: 1.4260 - val_accuracy: 0.6036
# Epoch 33/50
# 169/169 [==============================] - 12s 73ms/step - loss: 0.6551 - accuracy: 0.7279 - val_loss: 1.1432 - val_accuracy: 0.6355
# Epoch 34/50
# 169/169 [==============================] - 12s 73ms/step - loss: 0.6481 - accuracy: 0.7404 - val_loss: 1.3703 - val_accuracy: 0.6147
# Epoch 35/50
# 169/169 [==============================] - 12s 73ms/step - loss: 0.6702 - accuracy: 0.7311 - val_loss: 1.8483 - val_accuracy: 0.5650
# Epoch 36/50
# 169/169 [==============================] - 12s 73ms/step - loss: 0.6684 - accuracy: 0.7476 - val_loss: 1.4965 - val_accuracy: 0.5813
# Epoch 37/50
# 169/169 [==============================] - 12s 73ms/step - loss: 0.6067 - accuracy: 0.7626 - val_loss: 2.6599 - val_accuracy: 0.5204
# Epoch 38/50
# 169/169 [==============================] - 12s 73ms/step - loss: 0.5998 - accuracy: 0.7685 - val_loss: 1.4533 - val_accuracy: 0.6013
# Epoch 39/50
# 169/169 [==============================] - 12s 73ms/step - loss: 0.5647 - accuracy: 0.7760 - val_loss: 2.3140 - val_accuracy: 0.5471
# Epoch 40/50
# 169/169 [==============================] - 12s 73ms/step - loss: 0.5820 - accuracy: 0.7797 - val_loss: 1.5315 - val_accuracy: 0.5976
# Epoch 41/50
# 169/169 [==============================] - 12s 73ms/step - loss: 0.5830 - accuracy: 0.7721 - val_loss: 1.1732 - val_accuracy: 0.6392
# Epoch 42/50
# 169/169 [==============================] - 12s 73ms/step - loss: 0.5487 - accuracy: 0.7889 - val_loss: 1.2511 - val_accuracy: 0.6563
# Epoch 43/50
# 169/169 [==============================] - 12s 73ms/step - loss: 0.5408 - accuracy: 0.7945 - val_loss: 5.9811 - val_accuracy: 0.3764
# Epoch 44/50
# 169/169 [==============================] - 12s 73ms/step - loss: 0.5229 - accuracy: 0.8023 - val_loss: 1.4027 - val_accuracy: 0.6154
# Epoch 45/50
# 169/169 [==============================] - 12s 73ms/step - loss: 0.5148 - accuracy: 0.8047 - val_loss: 3.9509 - val_accuracy: 0.4944
# Epoch 46/50
# 169/169 [==============================] - 12s 73ms/step - loss: 0.5218 - accuracy: 0.8012 - val_loss: 1.2094 - val_accuracy: 0.6622
# Epoch 47/50
# 169/169 [==============================] - 12s 73ms/step - loss: 0.4806 - accuracy: 0.8144 - val_loss: 2.7048 - val_accuracy: 0.5390
# Epoch 48/50
# 169/169 [==============================] - 12s 73ms/step - loss: 0.4840 - accuracy: 0.8162 - val_loss: 1.2887 - val_accuracy: 0.6704
# Epoch 49/50
# 169/169 [==============================] - 12s 73ms/step - loss: 0.5017 - accuracy: 0.8027 - val_loss: 1.7396 - val_accuracy: 0.6036
# Epoch 50/50
# 169/169 [==============================] - 12s 73ms/step - loss: 0.4725 - accuracy: 0.8186 - val_loss: 1.3119 - val_accuracy: 0.6778

# %%
plotmodel(history_4)

# %% [markdown]
# Observations on Model 4
#
# The training accuracy on model_4 is around 81.86% where as the validation accuracy is around 67.78%. We managed to bring down the overfitting compared to model_3 where the training accuracy was 98.35%. However the model still needs to be tweaked

# %%
# Model 5 - More Layers

# %%
# Setting Cache and Prefetch using Keras AUTOTUNE
#Please note: This will be called before every model so that the cache is shuffled
AUTOTUNE = tf.data.AUTOTUNE
train_ds = train_ds.cache().shuffle(1000).prefetch(buffer_size=AUTOTUNE)
val_ds = val_ds.cache().prefetch(buffer_size=AUTOTUNE)

# %%
#Model_5
# More Layers added and combination of dropouts added
model_5 = Sequential([
    layers.Rescaling(1./255, input_shape=(img_height, img_width, 3)),
    #
    layers.Conv2D(16,3,padding="same", activation='relu'),
    layers.BatchNormalization(),
    layers.Conv2D(16,3,padding="same", activation='relu'),
    layers.BatchNormalization(),
    layers.MaxPooling2D(pool_size=(2, 2)),
    layers.Dropout(0.1),
    #
    layers.Conv2D(32,3,padding="same", activation='relu'),
    layers.BatchNormalization(),
    layers.Conv2D(32,3,padding="same", activation='relu'),
    layers.BatchNormalization(),
    layers.MaxPooling2D(pool_size=(2, 2)),
    layers.Dropout(0.25),
    #
    layers.Conv2D(64,3,padding="same", activation='relu'),
    layers.BatchNormalization(),
    layers.Conv2D(64,3,padding="same", activation='relu'),
    layers.BatchNormalization(),
    layers.MaxPooling2D(pool_size=(2, 2)),
    layers.Dropout(0.1),
    #
    layers.Conv2D(128,3,padding="same", activation='relu'),
    layers.BatchNormalization(),
    layers.Conv2D(128,3,padding="same", activation='relu'),
    layers.BatchNormalization(),
    layers.MaxPooling2D(pool_size=(2, 2)),
    layers.Dropout(0.25),
    #
    layers.Conv2D(256,3,padding="same", activation='relu'),
    layers.BatchNormalization(),
    layers.Conv2D(256,3,padding="same", activation='relu'),
    layers.BatchNormalization(),
    layers.MaxPooling2D(pool_size=(2, 2)),
    layers.Dropout(0.1),
    #
    layers.Conv2D(512,3,padding="same", activation='relu'),
    layers.BatchNormalization(),
    layers.Conv2D(512,3,padding="same", activation='relu'),
    layers.BatchNormalization(),
    layers.MaxPooling2D(pool_size=(2, 2)),
    layers.Dropout(0.25),
    #
    layers.Conv2D(1024,3,padding="same", activation='relu'),
    layers.BatchNormalization(),
    layers.Conv2D(1024,3,padding="same", activation='relu'),
    layers.BatchNormalization(),
    layers.MaxPooling2D(pool_size=(2, 2)),
    layers.Dropout(0.1),

    #Flatten Layer
    layers.Flatten(),
    #Dense Layer
    layers.Dense(2048,activation='relu'),
    layers.Dropout(0.25),
    #Softmax Layer
    layers.Dense(len(class_names),activation='softmax')
])

# %%
model_5.compile(optimizer="Adam",loss="sparse_categorical_crossentropy",metrics=["accuracy"])

model_5.summary()
# Out:
# Model: "sequential_5"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  rescaling_4 (Rescaling)     (None, 180, 180, 3)       0
#
#  conv2d_15 (Conv2D)          (None, 180, 180, 16)      448
#
#  batch_normalization_9 (Batc  (None, 180, 180, 16)     64
#  hNormalization)
#
#  conv2d_16 (Conv2D)          (None, 180, 180, 16)      2320
#
#  batch_normalization_10 (Bat  (None, 180, 180, 16)     64
#  chNormalization)
#
#  max_pooling2d_12 (MaxPoolin  (None, 90, 90, 16)       0
#  g2D)
#
#  dropout_4 (Dropout)         (None, 90, 90, 16)        0
#
#  conv2d_17 (Conv2D)          (None, 90, 90, 32)        4640
#
#  batch_normalization_11 (Bat  (None, 90, 90, 32)       128
#  chNormalization)
#
#  conv2d_18 (Conv2D)          (None, 90, 90, 32)        9248
#
#  batch_normalization_12 (Bat  (None, 90, 90, 32)       128
#  chNormalization)
#
#  max_pooling2d_13 (MaxPoolin  (None, 45, 45, 32)       0
#  g2D)
#
#  dropout_5 (Dropout)         (None, 45, 45, 32)        0
#
#  conv2d_19 (Conv2D)          (None, 45, 45, 64)        18496
#
#  batch_normalization_13 (Bat  (None, 45, 45, 64)       256
#  chNormalization)
#
#  conv2d_20 (Conv2D)          (None, 45, 45, 64)        36928
#
#  batch_normalization_14 (Bat  (None, 45, 45, 64)       256
#  chNormalization)
#
#  max_pooling2d_14 (MaxPoolin  (None, 22, 22, 64)       0
#  g2D)
#
#  dropout_6 (Dropout)         (None, 22, 22, 64)        0
#
#  conv2d_21 (Conv2D)          (None, 22, 22, 128)       73856
#
#  batch_normalization_15 (Bat  (None, 22, 22, 128)      512
#  chNormalization)
#
#  conv2d_22 (Conv2D)          (None, 22, 22, 128)       147584
#
#  batch_normalization_16 (Bat  (None, 22, 22, 128)      512
#  chNormalization)
#
#  max_pooling2d_15 (MaxPoolin  (None, 11, 11, 128)      0
#  g2D)
#
#  dropout_7 (Dropout)         (None, 11, 11, 128)       0
#
#  conv2d_23 (Conv2D)          (None, 11, 11, 256)       295168
#
#  batch_normalization_17 (Bat  (None, 11, 11, 256)      1024
#  chNormalization)
#
#  conv2d_24 (Conv2D)          (None, 11, 11, 256)       590080
#
#  batch_normalization_18 (Bat  (None, 11, 11, 256)      1024
#  chNormalization)
#
#  max_pooling2d_16 (MaxPoolin  (None, 5, 5, 256)        0
#  g2D)
#
#  dropout_8 (Dropout)         (None, 5, 5, 256)         0
#
#  conv2d_25 (Conv2D)          (None, 5, 5, 512)         1180160
#
#  batch_normalization_19 (Bat  (None, 5, 5, 512)        2048
#  chNormalization)
#
#  conv2d_26 (Conv2D)          (None, 5, 5, 512)         2359808
#
#  batch_normalization_20 (Bat  (None, 5, 5, 512)        2048
#  chNormalization)
#
#  max_pooling2d_17 (MaxPoolin  (None, 2, 2, 512)        0
#  g2D)
#
#  dropout_9 (Dropout)         (None, 2, 2, 512)         0
#
#  conv2d_27 (Conv2D)          (None, 2, 2, 1024)        4719616
#
#  batch_normalization_21 (Bat  (None, 2, 2, 1024)       4096
#  chNormalization)
#
#  conv2d_28 (Conv2D)          (None, 2, 2, 1024)        9438208
#
#  batch_normalization_22 (Bat  (None, 2, 2, 1024)       4096
#  chNormalization)
#
#  max_pooling2d_18 (MaxPoolin  (None, 1, 1, 1024)       0
#  g2D)
#
#  dropout_10 (Dropout)        (None, 1, 1, 1024)        0
#
#  flatten_4 (Flatten)         (None, 1024)              0
#
#  dense_8 (Dense)             (None, 2048)              2099200
#
#  dropout_11 (Dropout)        (None, 2048)              0
#
#  dense_9 (Dense)             (None, 9)                 18441
#
# =================================================================
# Total params: 21,010,457
# Trainable params: 21,002,329
# Non-trainable params: 8,128
# _________________________________________________________________

# %%
epochs = 50
history_5 = model_5.fit(train_ds,validation_data=val_ds,epochs=epochs)
# Out:
# Epoch 1/50
# 169/169 [==============================] - 26s 136ms/step - loss: 2.4218 - accuracy: 0.3088 - val_loss: 2.6312 - val_accuracy: 0.1069
# Epoch 2/50
# 169/169 [==============================] - 21s 127ms/step - loss: 1.6672 - accuracy: 0.3987 - val_loss: 2.1479 - val_accuracy: 0.2108
# Epoch 3/50
# 169/169 [==============================] - 21s 127ms/step - loss: 1.4957 - accuracy: 0.4277 - val_loss: 1.8249 - val_accuracy: 0.3274
# Epoch 4/50
# 169/169 [==============================] - 21s 127ms/step - loss: 1.4297 - accuracy: 0.4616 - val_loss: 1.5257 - val_accuracy: 0.3950
# Epoch 5/50
# 169/169 [==============================] - 21s 127ms/step - loss: 1.3925 - accuracy: 0.4675 - val_loss: 1.7435 - val_accuracy: 0.3987
# Epoch 6/50
# 169/169 [==============================] - 21s 127ms/step - loss: 1.2898 - accuracy: 0.5102 - val_loss: 1.8786 - val_accuracy: 0.4128
# 169/169 [==============================] - 21s 127ms/step - loss: 0.1784 - accuracy: 0.9306 - val_loss: 1.3143 - val_accuracy: 0.7038
# Epoch 45/50
# 169/169 [==============================] - 21s 127ms/step - loss: 0.1599 - accuracy: 0.9392 - val_loss: 1.2354 - val_accuracy: 0.7120
# Epoch 46/50
# 169/169 [==============================] - 21s 127ms/step - loss: 0.1399 - accuracy: 0.9462 - val_loss: 1.1744 - val_accuracy: 0.7305
# Epoch 47/50
# 169/169 [==============================] - 21s 127ms/step - loss: 0.1263 - accuracy: 0.9534 - val_loss: 1.1173 - val_accuracy: 0.7550
# Epoch 48/50
# 169/169 [==============================] - 21s 127ms/step - loss: 0.1613 - accuracy: 0.9407 - val_loss: 1.3934 - val_accuracy: 0.6785
# Epoch 49/50
# 169/169 [==============================] - 21s 127ms/step - loss: 0.1452 - accuracy: 0.9420 - val_loss: 1.0798 - val_accuracy: 0.7624
# Epoch 50/50
# 169/169 [==============================] - 21s 127ms/step - loss: 0.1700 - accuracy: 0.9434 - val_loss: 1.2993 - val_accuracy: 0.7068

# %%
plotmodel(history_5)

# %% [markdown]
# Observation on Model_5
#
# Model 5 took the longest time of all models here to fit.
# The model shows a slightly better accuracy on validation data compared to the previous model. Nevertheless it is still overfitting still.
# We could increase the layers so and also do some l1 regularization, but we will stop model building now as have already built 5 models

# %%
###
#    Moment of truth : Lets see how the models created perform on test data
###

# %%
# Loading the test data to test_ds using keras
test_ds = tf.keras.utils.image_dataset_from_directory(
  data_dir_test,image_size=(img_height, img_width))
# Out:
# Found 118 files belonging to 9 classes.

# %%
# Function to predict on test data using every model created

def calculate_on_test(modelname):
    
    correct=0
    for name in class_names:
        Test_dir = os.path.join(data_dir_test, name, '*')
        Test_dir = glob(Test_dir)
        for x in range(len(Test_dir)):
            Test_image = load_img(Test_dir[x],target_size=(180,180,3))
            img = np.expand_dims(Test_image,axis=0)
            pred = modelname.predict(img)
            pred = np.argmax(pred)
            pred_class = class_names[pred]
            if(name==pred_class):
                correct +=1
    print("Number of images from the test set that were classified correctly by Model  : ",correct)
    percent=correct/118*100
    print("Which is ",percent,"percent of the whole testset")

# %%
#Checking classification on different models created

# %%
# Checking Model 1 
calculate_on_test(model_1)
# Out:
# 1/1 [==============================] - 0s 129ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 16ms/step
# Number of images from the test set that were classified correctly by Model  :  42
# Which is  35.59322033898305 percent of the whole testset

# %%
# Checking Model 2
calculate_on_test(model_2)
# Out:
# 1/1 [==============================] - 0s 68ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 20ms/step
# Number of images from the test set that were classified correctly by Model  :  26
# Which is  22.033898305084744 percent of the whole testset

# %%
# Checking Model 3
calculate_on_test(model_3)
# Out:
# 1/1 [==============================] - 0s 92ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 18ms/step
# Number of images from the test set that were classified correctly by Model  :  44
# Which is  37.28813559322034 percent of the whole testset

# %%
# Checking Model 4
calculate_on_test(model_4)
# Out:
# 1/1 [==============================] - 0s 453ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 19ms/step
# Number of images from the test set that were classified correctly by Model  :  44
# Which is  37.28813559322034 percent of the whole testset

# %%
# Checking Model 5
calculate_on_test(model_5)
# Out:
# 1/1 [==============================] - 1s 504ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 20ms/step
# Number of images from the test set that were classified correctly by Model  :  53
# Which is  44.91525423728814 percent of the whole testset

# %%
#Model 5 performed the best on test data, predicting 53 classes correctly for 118 images (44.91%)
